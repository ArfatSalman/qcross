# %%
import os
import json
from qcross.summarize import summarize_groups, get_exception_data

folder = 'data/completed-execs'
s = []

# %%
# %load_ext autoreload
# %autoreload 2

# %%
summarize_groups()
# Out:
# {'qasm3_exceptions': {'groups': [['type error']],
#   'repo': ['Qiskit/qiskit-terra', 'Qiskit/qiskit-qasm3-import']},
#  'qpy_exceptions': {'groups': [], 'repo': ['Qiskit/qiskit-terra']},
#  'qiskit_followup_exceptions': {'groups': [['Cannot unroll the circuit to the given basis Instruction id not found in equivalence library and no rule found to expand'],
#    ['Duplicate declaration for gate rzx at line file nPrevious occurrence at line file'],
#    ['Cannot find gate definition for csx line file']],
#   'repo': ['Qiskit/qiskit-terra']}}

# %%
get_exception_data()
# Out:
#                              prog_id  \
# 0   9e26bf558a4548ff920a42d2fedd3793
# 1   1cddcf17eedd4b089d0e59b4d0437665
# 2   f9898b467e494f2087850ed502d3a809
# 3   253516626a494895acff4f265b285543
# 4   a7f74c723c20489f85114315ec3eab96
# 5   96d8eea9254648479bdabe6d111b6e82
# 6   d7d8d2c06b1345e890b75181f331f95c
# 7   13d5a528ac58412484728a3aa1631d0d
# 8   26a88c446d7848d18638143432674e96
# 9   dc55490ec5c44045a12ba543b9c9c7e3
# 10  98891e1eb26348deab5473c6f750578d
# 11  476f9f0ff5dc4fa9a642884f114dfdfc
# 12  14d5b8b8e71546f2acaedd67d03b0616
# 13  83c982ab406440b19ca801ed82148231
# 14  07373bd665794e399a403dd50f4d653b
#
#                      qiskit.qiskit_followup.exception  \
# 0   Cannot unroll the circuit to the given basis, ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Duplicate declaration for gate 'rzx' at line 4...
# ...
