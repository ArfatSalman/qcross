# %%
import cirq
from cirq.contrib.qasm_import import circuit_from_qasm

# Pick a qubit.
qubit = cirq.GridQubit(10, 0)

# Create a circuit
circuit = cirq.Circuit(
    cirq.X(qubit)**0.5,  # Square root of NOT.
    cirq.measure(qubit, key='m'),  # Measurement.
    cirq.measure(qubit, key='x')  # Measurement.
)

circuit = circuit_from_qasm(cirq.qasm(circuit))

# Simulate the circuit several times.
simulator = cirq.Simulator()

result = simulator.run(circuit, repetitions=20)
print("Results:")
print(result)
# Out:
# Results:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 21
#      19 result = simulator.run(circuit, repetitions=20)
#      20 print("Results:")
# ---> 21 print(result)
#
# File ~/Desktop/qc-test/venv/lib/python3.9/site-packages/cirq/study/result.py:391, in ResultDict.__str__(self)
#     390 def __str__(self) -> str:
# --> 391     return _keyed_repeated_bitstrings(self.measurements)
#
# File ~/Desktop/qc-test/venv/lib/python3.9/site-packages/cirq/study/result.py:343, in ResultDict.measurements(self)
#     341         reps, instances, qubits = data.shape
#     342         if instances != 1:
# --> 343             raise ValueError('Cannot extract 2D measurements for repeated keys')
#     344         self._measurements[key] = data.reshape((reps, qubits))
#     345 return self._measurements
#
# ValueError: Cannot extract 2D measurements for repeated keys

# %%
result
# Out:
# m_cr0_0=...
# m_cr1_0=...
# m_cr2_0=...
# m_cr3_0=...
